# %% [markdown]
# # Assignment 4
# ## Lercio headlines generator
#
# Implementation and training of a character based RNN in pytorch to generate headlines in the style of the satirical news website [Lercio](https://www.lercio.it/).

# %% [markdown]
# ### Environment setup and execution instructions
# The project depends on the following libraries:
#
# pytorch: ML library for python
# unidecode: used to convert unicode characters to the closest ASCII representation
# tqdm: used to display progress bars
# matplotlib: loss graph plotting
#
# The project is contained in a single jupyter notebook, which can be executed cell by cell. The notebook is self contained, every external resource is downloaded and extracted automatically.
#
# The `EXECUTE_TRAINING` flag can be used to disable training and only load a pre-trained model. Note that this flag just halts execution of the training cell. In order to generate samples with the pretrained model, the corresponding cell (last one) must be executed manually.

# %%
EXECUTE_TRAINING = True

# !pip install unidecode tqdm
# !rm lercio_headlines.csv
# !wget --no-check-certificate https://elearning.di.unipi.it/pluginfile.php/46562/mod_assign/intro/lercio_headlines.csv

# %% [markdown]
# ### Model definition
#
# The model was somewhat inspired by the [Char-RNN](https://github.com/spro/char-rnn.pytorch).
# It is a simple RNN module based on GRU cells. It takes as input a batch of characters (encoded as one-hot vectors), passes them through `n_layers` layers of GRU, and after a fully connected layer, outputs a probability distribution over the characters (SoftMax).

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class CharRNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, n_layers=1, dropout = 0):
        super(CharRNN, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers

        self.rnn = nn.GRU(input_size, hidden_size, n_layers, dropout=dropout, batch_first=True).to(DEVICE)
        self.fc = nn.Linear(hidden_size, output_size).to(DEVICE)
        self.softmax = nn.LogSoftmax(dim=2).to(DEVICE)
        self.losses = None

    def forward(self, input, hidden):
        output, hidden = self.rnn(input, hidden)
        output = self.fc(output)
        output = self.softmax(output)
        return output, hidden

    # Initialize hidden state (used before forward pass for each mini-batch)
    def init_hidden(self, batch_size):
        return Variable(torch.zeros(self.n_layers, batch_size, self.hidden_size)).to(DEVICE)

# %% [markdown]
# ### Data loading and preprocessing
#
# The data is loaded from the CSV, treating each row as a separate headline. In order to remove special characters, each line is passed through unidecode, which takes the raw text and returns a string with all non-standard characters replaced with their closest standard equivalent.
# Then a dictionary `vocab` is created, mapping each character to a unique index.

# %%
from unidecode import unidecode

def readLines(filename):
    with open(filename, 'r', encoding='utf-8') as f:
        return [unidecode(line) for line in f]
    
# Read the list of headlines from the csv
headlines = readLines('./lercio_headlines.csv')
headlines = sorted(headlines, key=len, reverse=True)

# Create a list of all the unique letters in the headlines
all_letters_list = list(set(''.join(headlines))) + ['✕']
all_letters_list.sort()
all_letters = ''.join(all_letters_list)
num_letters = len(all_letters)

# Create a dictionary mapping each letter to the corresponding index in the list of all letters
vocab = {all_letters[i]: i for i in range(num_letters)}

# %% [markdown]
# ### Input tensors creation
#
# In order to speed up training, a batched approach is used. Since the headlines sequences are of different lengths, the sequences are padded with a special character `✕` not present in the text. As a result of this, two important tensors are created: `headlines_tensor` and `headlines_one_hot`:
# - `headlines_tensor` is a tensor of shape `(batch_size, max_headline_length)`, containing the indices of the characters in the headlines.
# - `headlines_one_hot` is a tensor of shape `(batch_size, max_headline_length, vocab_size)`, containing the one-hot encoding of the characters in the headlines.
# The first one is needed in order to compute the loss, while the second one is needed as input to the model.

# %%
# Convert headlines to tensors of character indices (vocab)
headlines_tensor_list = [torch.tensor([vocab[letter] for letter in headline]) for headline in headlines]
# Pad headlines tensor to common length
headlines_tensor = nn.utils.rnn.pad_sequence(headlines_tensor_list, batch_first=True, padding_value=vocab['✕']).to(DEVICE)
# Convert the padded dataset to one-hot encoding
headlines_one_hot = nn.functional.one_hot(headlines_tensor, num_classes=num_letters).to(torch.float32).to(DEVICE)

# %% [markdown]
# ### Sampling
#
# Two sampling methods are implemented: `generate` and `generate_normal`
# - `generate` is just given a starting string and a single temperature value and keeps generating characters until it reaches `max_len` characters or the stop character `\n` is encountered.
# - `generate_normal` is given instead a starting string, and two parameters `mean_temp` and `std_temp`; for each character, the temperature is sampled from a normal distribution. The generation stops with the same criteria as before.

# %%
import numpy as np

# Given a line of text, convert it to the respective one-hot encoding
def input_to_onehot(line):
    return nn.functional.one_hot(torch.tensor([vocab[c] for c in line]), num_letters).to(torch.float32).to(DEVICE).view(1, -1, num_letters)

@torch.no_grad()
def generate(model, start_string, temperature = 1, max_len = 200):
    input = input_to_onehot(start_string)
    hidden = model.init_hidden(1)

    output_name = start_string

    for j in range(input.shape[1] - 1):
        output, hidden = model(input[:, j, :].view(1, 1, num_letters), hidden)
    for i in range(max_len):
        output, hidden = model(input[0, -1].view(1, 1, num_letters), hidden)
        if temperature == 0:
            topi = output.data.view(-1).argmax()
        else:
            output_dist = output.data.view(-1).div(temperature).exp()
            topi = torch.multinomial(output_dist, 1)[0]
        if topi == all_letters.find('\n'):
            break
        else:
            letter = all_letters[topi]
            output_name += letter
        input = input_to_onehot(letter)

    return output_name

@torch.no_grad()
def generate_normal(model, start_string, mean_temp = 0, std_temp = 0, max_len = 200):
    input = input_to_onehot(start_string)
    hidden = model.init_hidden(1)

    output_name = start_string

    for j in range(input.shape[1] - 1):
        output, hidden = model(input[:, j, :].view(1, 1, num_letters), hidden)
    for i in range(max_len):
        output, hidden = model(input[0, -1].view(1, 1, num_letters), hidden)

        temperature = np.random.normal(mean_temp, std_temp)
        temperature = abs(temperature)

        # Since a too-low temperature would result in an exception given by limited numerical precision, this piece of code is encapsulated in a try-except block which handles the exception by getting the most probable character without temperature. 
        try:
            output_dist = output.data.view(-1).div(temperature).exp()
            topi = torch.multinomial(output_dist, 1)[0]
        except RuntimeError:
            topi = output.data.view(-1).argmax()
        if topi == all_letters.find('\n'):
            break
        else:
            letter = all_letters[topi]
            output_name += letter
        input = input_to_onehot(letter)

    return output_name

# %% [markdown]
# ### Training
#
# The model is trained using the Adam optimizer, with a starting learning rate of 0.01. A scheduler is used to decrease the learning rate as the training proceeds.
#
# The loss is computed using the `NLLLoss` function, using the `ignore_index` parameter set to the padding character (without this the model often would get stuck ouputting only padding chars).
#
# In order to fit the model in the GPU memory, the full set of headlines is split into mini-batches.
#
# Gradient clipping is used in order to mitigate some loss spikes.
#
# Tensorboard is used to monitor the loss.
#
# #### Training loop
# The key points of the training loop are:
# - The headlines are split in `splits` mini-batches. For each one:
#     - The hidden states are initialized.
#     - The loss (for the MB) is reset.
#     - For each character of the sequences:
#         - The model is fed the current character and the hidden states.
#         - The loss is computed and added to the sum of losses.
#     - The gradients are computed and clipped.
#     - The optimizer is updated. (adam)
# - The average loss for the epoch is computed.
# - The scheduler is updated (learning rate).
#
# Every 50 epochs, some sample headlines are generated and printed.
#
# #### Results
#
# It was found empirically that an optimal loss value is around `0.20-0.10`. Above this values, the generated phrases are often not readable, while below this values the model tends to overfit and generate only phrases from the training set.

# %%
import string
import random
import numpy as np
from pathlib import Path
from tqdm.notebook import tqdm
upper = string.ascii_uppercase

# If no training requested, skip the cell
if EXECUTE_TRAINING:
    from torch.utils.tensorboard import SummaryWriter
    writer = SummaryWriter()


    # Remains of the teacher forcing tests
    # TFR_TARGET = 0.15
    # TFR_MAX = 1
    # TFR_MIN = 0.8

    # Gradient clipping value
    CLIPPING = 0.1

    padding = torch.tensor([vocab['✕']], device=DEVICE)

    epochs = 1000
    splits = 5

    PARAM = {
        'HIDDEN_SIZE': 250,
        'N_LAYERS': 2,
        'DROPOUT': 0
    }


    losses = []
    HIDDEN_SIZE = PARAM['HIDDEN_SIZE']
    N_LAYERS    = PARAM['N_LAYERS']
    DROPOUT     = PARAM['DROPOUT']
    base_name = f'H{HIDDEN_SIZE}_N{N_LAYERS}_D{DROPOUT:.2f}_'

    rnn = CharRNN(num_letters, HIDDEN_SIZE, num_letters, N_LAYERS, DROPOUT).to(DEVICE)
    criterion = nn.NLLLoss(ignore_index=vocab['✕'])

    # Initialize optimizer and lr scheduler with 0.01 initial lr, linear decay for 500 epochs up to 0.0001, then constant for the rest
    decoder_optimizer = torch.optim.RAdam(rnn.parameters(), lr=0.01)
    scheduler = torch.optim.lr_scheduler.LinearLR(decoder_optimizer, 1, 0.01, 500)

    one_hot = headlines_one_hot

    try:
        tfr = 1
        for epoch in tqdm(range(epochs), total=epochs):
            loss_perms = []
            # Split the data into `split` parts and train on each part
            perms = np.array_split(np.random.permutation(one_hot.shape[0]), splits)
            for perm in perms:
                input_tensor = one_hot[perm, :-1, :]
                output_tensor = headlines_tensor[perm, 1:]
                perm_size = input_tensor.shape[0]
                hidden = rnn.init_hidden(perm_size)
                rnn.zero_grad()

                loss = 0
                character_tensor = input_tensor[:, 0:1, :]
                # Send sequience through the network one character at a time
                for c in range(input_tensor.shape[1]):
                    output, hidden = rnn(character_tensor, hidden)
                    # Since `criterion` is ignoring the padding character, once all the characters in the mini-batch are padding, the loss would be NaN.
                    # To avoid this, we set the loss to 0 manually.
                    if (output_tensor[:, c:c+1] == padding).all():
                        l = 0
                    else:
                        l = criterion(output.mT, output_tensor[:, c:c+1])
                    loss += l
                    # Teacher forcing (not used, always TRUE)
                    if random.random() < tfr:
                        character_tensor = input_tensor[:, c+1:c+2, :]
                    else:
                        character_tensor = output
                # Average the loss over the sequence length
                loss /= input_tensor.shape[1]
                    
                # Backpropagate and clip gradients
                loss.backward()
                torch.nn.utils.clip_grad_norm_(rnn.parameters(), CLIPPING)

                decoder_optimizer.step()
                loss_perms.append(loss.data.item())
            loss_epoch = np.mean(loss_perms)
            losses.append(loss_epoch)
            writer.add_scalar('Loss/train', loss_epoch, epoch)
            writer.add_scalar('Learning rate', scheduler.get_last_lr()[0], epoch)
            scheduler.step()
            # tfr = min(1, TFR_MIN + (TFR_MAX - TFR_MIN) * (loss / TFR_TARGET))

            # Every 50 epochs, generate some samples
            if epoch % 50 == 49:
                print(f'Epoch: {epoch},\tloss: {loss_epoch}')
                start = random.choice(upper)
                print(f'T: 0.05  S: {generate(rnn, start, 0.05)}')
                print(f'T: 0.1   S: {generate(rnn, start, 0.1)}')
                print(f'T: 0.2   S: {generate(rnn, start, 0.2)}')
                print(f'T: .7±.4 S: {generate_normal(rnn, start, .7, .4)}')
    except KeyboardInterrupt:
        print('Interrupted')
    finally:
        # Once the training is done (or interrupted), save the model
        print('Saving model')
        model_name = f'H{HIDDEN_SIZE}_N{N_LAYERS}_D{DROPOUT:.2f}_E{epoch}_L{loss_epoch:.2f}_rnn.pt'
        rnn.losses = losses
        torch.save(rnn, model_name)
        writer.flush()
        writer.close()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch: 49,	loss: 1.5148557662963866
# T: 0.05  S: Giandi di sura di conta di scordi di scordi di sulla sche scondione della schiena della schiene della Famiglione e le vittime
# T: 0.1   S: Giandino di sua sconde di cardina di sulla scordi di sconde della sche sulla schiena della sparatoria della sparatorio e le vittime
# T: 0.2   S: Gianti di cordia di sulla scordi di sconde di stalla scome della sparata della schiena della sparatorio e le vittime della
# T: .7±.4 S: Gimake maeti como di girende il unna della Walunna in copria da si confer pur guondo gli Stmanta
# Epoch: 99,	loss: 0.9091985821723938
# T: 0.05  S: Oriente di condanzi di merda il primo per la senza del carcere di Papa Papa
# T: 0.1   S: Oriano a Radio2 Social Corenti e si fa scopre che si fa a casa del proprio non esiste di merda
# T: 0.2   S: Olita il primo per la fila di mare in un contro di essere di merda in un contratto
# T: .7±.4 S: Oriente la settimana della morta sulla sermazione delle bambini che vecchuo per reservisi alle sestituzione
# Epoch: 149,	loss: 0.6680074095726013
# T: 0.05  S: Zoologia scopre che la segnato da un altro poi si sciolgano e la mano in campo di concerto
# T: 0.1   S: Zoologia di Casaleggio per la prima chimica a mandante in campo di convermizza
# T: 0.2   S: Zoologia di Maria Di Maio: "Non si propone un lavoro per la prossima strada"
# T: .7±.4 S: Zoologo grazie un solo in conta della pare di Fermania
# Epoch: 199,	loss: 0.7186226725578309
# T: 0.05  S: Esce il primo calcio nella scuole: "La manda a casa del setto che sono i sequestra li test"
# T: 0.1   S: Esce il primo completto per farsi essere la casa del cazzole del PD
# T: 0.2   S: Esce il primo calcio nella scuola e fa un porta di essere la butta la cattattale
# T: .7±.4 S: Esce in gala in accille le schiente otto a fare un'altra la macchina di Papa Francesco
# Epoch: 249,	loss: 0.4774072110652924
# T: 0.05  S: X ricorda alla testa di prossime e scopre che il cucinale a piedi e viene scomparsa
# T: 0.1   S: X ricorda alla testa di prossime e scopre che il cucinale a piedi e viene scomparsa
# T: 0.2   S: Xeliana come scambiata con l'accolta la carica di Berlusconi delle vita a Porta con l'altro una copietth
# T: .7±.4 S: Xelisondava notizio Claucher per vince i calcini in un colpo di non essere i tumenti di applausi
# Epoch: 299,	loss: 0.41012701392173767
# T: 0.05  S: Mario Dio sara una prima napoletanazione del minisolo di Berlusconi
# T: 0.1   S: Mario Roggio durante una settima della polizia il primo colpo
# T: 0.2   S: Mario Roggio estrare in un campo sempre a rimiomeriare il piano-senito
# T: .7±.4 S: Mario Navala al punto di risposta: "Il tormano decini di Vermersa per diffurborata"
# Epoch: 349,	loss: 0.3676101565361023
# T: 0.05  S: Oriana una settima della Lega per il rispontaggio filo dell'anno
# T: 0.1   S: Oriana una settima della Lega per un bungo parlare il proprio la decopola
# T: 0.2   S: Olimpiadi di sodia per la prima appartamentore del proprio Samanito
# T: .7±.4 S: OQIESTA SI DIMITI DI UMANESI DI STUDENTO: "EBAGGIO MALESSA"
# Epoch: 399,	loss: 0.3327357292175293
# T: 0.05  S: Vaticano. In arrivo la forfo a casa delle autoniche dopo l'autovativor
# T: 0.1   S: Vince al corpo per risperto all'altro ": lienare il suo arbambrosto all'astarlo di Napolita
# T: 0.2   S: Vince al corpo per risperto la diretta di venti
# T: .7±.4 S: Virginia Raggi accusa frase va a farsi per il Berconz: Chimy Conta che samano per indietro il trapretto come sire
# Epoch: 449,	loss: 0.3087166607379913
# T: 0.05  S: Quali altre correggiare"
# T: 0.1   S: Quali altre correggiare" e scopre couda di essere ancora vivo
# T: 0.2   S: Quali altre correggiare"
# T: .7±.4 S: Quali rapuccia l'emergenza sullo Stretto e il reddito di cittadinanza
# Epoch: 499,	loss: 0.28201361894607546
# T: 0.05  S: Zoologia: il pressione del mondo di napolta dai soldi partira a Cassinale contro bisorimento
# T: 0.1   S: Zoologi rivelano: "Era torna"
# T: 0.2   S: Zoologo si fa tra fettelli per strada per la protazione di Gigi D'Alessio
# T: .7±.4 S: Zoologia. Gli bannare anche nell'attone su barriche"
# Epoch: 549,	loss: 0.27684231400489806
# T: 0.05  S: Ricerca rivela: "Sono sciopero da Ramini cannaro la moglie candelle del mondo"
# T: 0.1   S: Ricerca rivela: "Sono sciopero dei cazzo di finestra le mani di un bambino"
# T: 0.2   S: Ricerca rivela: "Sono sciopero da Ramini cannaro la moglie candelle del mondo"
# T: .7±.4 S: Ricerca rivela: "Senza la minuti di merda anche gli anziani mi avessina il fumo per solo"
# Epoch: 599,	loss: 0.27314533591270446
# T: 0.05  S: Quali altre come Regine Casini rivela: "Da il nome e santinali"
# T: 0.1   S: Quali altre come Renzi sara una esauco"
# T: 0.2   S: Qualsionale di Renzi si fara per assomi e gli amano una settimana a Hilloon
# T: .7±.4 S: Qualsi di far aggrespotti mi occato nei benzinisti come paratoria
# Epoch: 649,	loss: 0.27024211883544924
# T: 0.05  S: Casalinga si fa perde le cieco di assimorate a una settimana ma non c'e lo passa
# T: 0.1   S: Cassazione: "La giornale con livaltere di acqua e stato pianta"
# T: 0.2   S: Casaleggio assume recitaco: e contro il concorrente tra Povia
# T: .7±.4 S: Carode confessa: "Ho andra non demiglio insegnare il suo cappeller"
# Epoch: 699,	loss: 0.26768157482147215
# T: 0.05  S: Hacker di Piero Zyna e ritira il campionato di aver ambatto cantante
# T: 0.1   S: Hacker di Piero Zyna e ritira il campionato di aver ambatto cantante
# T: 0.2   S: Hacker difere di scimbiamo e scopre che il miglior e viene grandente solo crocio dimentano l'Intico
# T: .7±.4 S: Hackerato agli ospiti il divorzio della frase prima di Linio Riceo
# Epoch: 749,	loss: 0.26536130905151367
# T: 0.05  S: Yara. Peggiora la situaco dentro il posto di Berlusconi
# T: 0.1   S: Yahoo Santonale che si fara un meteo
# T: 0.2   S: Yahoo Santanche si fa prendere la mano e consinismo
# T: .7±.4 S: Yovolamente siffacciasioni di Boom Rattorta dal suo pocrinese
# Epoch: 799,	loss: 0.26323404908180237
# T: 0.05  S: Napoli. Pulicico giocatore di cani e incinta: trengerizzata con le camicerie
# T: 0.1   S: Non ci sono mai non un coccorsino a Bardatore per marmaniste
# T: 0.2   S: Napoli. Pulio culono i bambini in classita e fa uniconolizzata di bedegnoli
# T: .7±.4 S: NASCE TI '97 E VIAME DEI TOVAMO DEL BESTE. EUTA FUSCUNTO BANCESCE CON CANDIS
# Epoch: 849,	loss: 0.2610369622707367
# T: 0.05  S: Universita della vita e si ripreado la Madonna
# T: 0.1   S: Uomo si fa tatuare sul pene un pene piu lungo
# T: 0.2   S: Universita della vita e si fidati di nuovo un computto
# T: .7±.4 S: Uomo si fa tatuare uccide elettorale: carare su un foto di sety
# Epoch: 899,	loss: 0.2595245063304901
# T: 0.05  S: Quali altre corte una modelle estete Marole e Batteo Marte Di Maio: "Ho sentire nel canipo"
# T: 0.1   S: Quali altre come Regine Mediaso al corso di 'Qaentesco riesce a fare una pancatta
# T: 0.2   S: Quali altre cercate dall'abbandono anche regolare la Terra e fa esercito
# T: .7±.4 S: Quarantono di Redidi sbatterrato in una brancio e anni
# Epoch: 949,	loss: 0.258067125082016
# T: 0.05  S: Hacker di Piero Zyna: "Mi ritire i figli del canti nella nascia a casa degli giura!"
# T: 0.1   S: Hacker di Piero Zyna: "Se ne acconte piaccione con la manica"
# T: 0.2   S: Hacker di Piero Peolini risponde di mare
# T: .7±.4 S: Hacker diffamato il cane di Forza Italia per riccolto partone
# Epoch: 999,	loss: 0.25627673864364625
# T: 0.05  S: Mario Dio sul locale apre un arma il prima rompo ai trai respiri
# T: 0.1   S: Mattarella si accende gli spaziali di mangiatori
# T: 0.2   S: Mattarella si accende gli inferica al mondo con se stessa con le mani e di morti
# T: .7±.4 S: Morto il colledio '6004: GABADDDDDDDDDDDDDDDDDBDDGx4GBBBB44DDBBBB4SBBBBY4GBBB4ODBBD4GBBW44KDGCBBB44DBBBCZBBT&GBBBBB44DBBB44CxCBBBB44DDDDDDDDDDDDDDDGBBBBDDBBB4DDBB444DDBBBBx4CBBBB4GDGBBG44GBDDBBB444BBBW
# Saving model

# %% [markdown]
# ### Sampling
#
# This cell picks every model saved to disk (workspace dir, <name>_rnn.pt) and generates some headlines for each uppercase letter of the alphabet at different temperature values.
#
# The sampling is done using both the `generate` and `generate_normal` functions.
# Each UPPERCASE letter of the alphabet is used as a starting character, and the headlines are generated with both methods, and different parameters.

# %%
from matplotlib import pyplot as plt

models = [x for x in Path('.').iterdir() if '_rnn.pt' in str(x)]
fig, ax = plt.subplots(figsize=(10, 7))

for model in models:
    rnn = torch.load(model)
    rnn.train(False)

    ax.plot(rnn.losses, label=model)
    fig.legend()

    print(f'\n################## {model} ##################\n')

    for U in upper:
        print(f'------ {U} ------')
        print(f'T: 0       S: {generate(rnn, U, 0)}')
        print(f'T: 0.1     S: {generate(rnn, U, 0.1)}')
        print(f'T: 0.5     S: {generate(rnn, U, 0.5)}')
        print(f'T: 0.7     S: {generate(rnn, U, 0.7)}')
        print(f'T: 0.9     S: {generate(rnn, U, 0.9)}')
        print(f'T: 0±.4    S: {generate_normal(rnn, U, 0, 0.4)}')
        print(f'T: 0.5±.4  S: {generate_normal(rnn, U, 0.5, 0.4)}')
        print(f'T: 1±.7    S: {generate_normal(rnn, U, 1, 0.7)}')
# Out:
# ################## H350_N2_D0.00_E999_L0.06_rnn.pt ##################
#
# ------ A ------
# T: 0       S: Anziano seduto davanti al marciapiede di casa festeggia la milionesima macchina contata
# T: 0.1     S: Anziano dice che ai suoi tempi era tutto peggio di adesso
# T: 0.5     S: Assad sostituira Fazio a "Che tempo che fa"
# T: 0.7     S: Abolita l'ora legale per colpa della battuta "Era l'unica cosa legale rimasta in Italia"
# T: 0.9     S: AlItio Salane: non sa casa di cadrine che traviscata parra fuori da ricitere dalla scarcare
# T: 0±.4    S: Anziana milionaria lancia il primo cavolle: onga surcetto postare le sue pesalli che mi hanno vesta lea
# T: 0.5±.4  S: Anziano seduto davanti al concorso "Ataliale estate dispette a scuola bastetto"
# T: 1±.7    S: Assestado di venduto: piu ling con le strappo del Comubunge
# ------ B ------
# T: 0       S: Berlusconi annuncia un suo imminente annuncio
# T: 0.1     S: Berlusconi non spara cazzate da una settimana: figli per contaggi in Erriari
# T: 0.5     S: Basta liti sul costo delle prestazioni: anche le mignotte dovranno esporre i prezzi come i benzinai
# T: 0.7     S: Berlusconi: "Mai farfica mo la prossima stagione de una disinerati ma ricasce"ion aquilicarestini"
# T: 0.9     S: Battisti: "Mi sono fatto prendere perche non ho resistito al richiamo del boom economico"
# T: 0±.4    S: Berlusconi affidato a un centro anziani: "Organizzero delle tombolate eleganti"
# T: 0.5±.4  S: Bambino mette in crisi il Papa: "Perche Dio manda terremoti solo nelle zone sismiche?"
# T: 1±.7    S: Brevetta la prima abbasta all'edenterbento dei tasire e abbandono al diatolono di figa
# ------ C ------
# T: 0       S: Cassazione: "Lo spoiler e reato!"
# T: 0.1     S: Casalinga scopre che la tv puo anche essere spenta
# T: 0.5     S: Confessa omicidio ma non gli eggi quanto nessuno
# T: 0.7     S: Cane si fa piangere riesce a diventare mediamo e lo sgarcatura
# T: 0.9     S: Casalinga annoiata davante il salvate in un internota
# T: 0±.4    S: Cassazione: "Il tempo passato a sognare di lavorare va retribuito da quella della teste di ImarroTwEtto il tuto"
# T: 0.5±.4  S: Cassazione: "Lasci un commento diffamatorio su Facebook? La responsabilita e di chi ti ha venduto il pc"
# T: 1±.7    S: Cane di Manduage il primo lombardiardere e dora perdere le altri alma di Casaleggio C8
# ------ D ------
# T: 0       S: Di Maio promette: "Tutti i nostri parlamentari saranno dotati di tagliando antifrode"
# T: 0.1     S: Di Maio precisa: "La regola dice che non si possono fare piu di due mandati contemporaneamente"
# T: 0.5     S: Di Maio propone referendum per uscire dal Bitcoin
# T: 0.7     S: Disoccupato si finge tofale: avrei borseleo pesta le supere 52ck della Germania
# T: 0.9     S: Di Maio convince i cinesi a Nnognato poliBenze: chiusa alla euro
# T: 0±.4    S: Di Maio precisa: "La regola dice che non si possono fare piu di due mandati contemporaneamente"
# T: 0.5±.4  S: Di Maio scatenato: "Dal 2020 chiusura domenica la parte dell'anno per riponchi in maga per paula"
# T: 1±.7    S: Di Maio: l'altro bere
# ------ E ------
# T: 0       S: Esce il nuovo singolo di Povia: "Luca era per l'Euro"
# T: 0.1     S: Esce il nuovo singolo di Povia: "Luca era per l'Euro"
# T: 0.5     S: Esplosione in fabbrica gas esilarante. Protezione Civile invia Brignano per annullarne gli effetti
# T: 0.7     S: Estrazioni del Comerd celcuto in braccipeller: aMFemile di Donna
# T: 0.9     S: E Roncobilaccio la citta dove la didanzia al telefandole
# T: 0±.4    S: Esce il nuovo singolo di Povia: "Luca era per l'Euro"
# T: 0.5±.4  S: Entra nella sede del PD sale per Gino VITGLIO:
# T: 1±.7    S: Emilia-Romagna. Monanni San Grignano
# ------ F ------
# T: 0       S: Facebook introduce il pulsante "Non piace a Selvaggia Lucarelli"
# T: 0.1     S: Facebook introduce il pulsante "Non piace a Selvaggia Lucarelli"
# T: 0.5     S: Facebook introduce il pulsante "Partecipo e me ne sto in disparte"
# T: 0.7     S: Felipe Massa brava legge un libro e si rientra la moglie e trova Sarrey
# T: 0.9     S: Femen si fanno aumentare il suo regax porno ad un giorno sara un cantiere
# T: 0±.4    S: Fallito il primo raduno degli amanti dei raduni: erano tutti impegnati in altri raduni
# T: 0.5±.4  S: Fa credere al gatto di vivere a non avevo lavoro ha trova del Nord bann d'Italia negale
# T: 1±.7    S: Falsici torna nel 193% le dichiarazioni che grandini di "Chi si e nulcogale"
# ------ G ------
# T: 0       S: Giovane muore di vecchiaia
# T: 0.1     S: Giovane muore di vecchiaia
# T: 0.5     S: Gli anni '60 furono girati in uno studio televisivo
# T: 0.7     S: Giulia Grillo: "Ho molti amici vaccinati"
# T: 0.9     S: Giuliale ascelle per intrarto all'IO"
# T: 0±.4    S: Giovane precario vende cittadinanza italiana su eBay per 81 euro
# T: 0.5±.4  S: Giuliano Palma incide un disco di cover delle concertone su Facebook: da comprongi
# T: 1±.7    S: Giovane muore Virbologa il Vervelenge vuole
# ------ H ------
# T: 0       S: Hacker rende pubbliche le identita di migliaia di alcolisti anonimi
# T: 0.1     S: Hacker ruba e mette onora il PD alle auto. ma e con sentenza tramogeni
# T: 0.5     S: Hacker ruba e mette on il trasferimento degli italiani tanti dimentica alle 6 di crimini
# T: 0.7     S: Hackerato account di Sanrey Culante venta e porto non zoo alle 22
# T: 0.9     S: Ha telefonato zio Luigi
# T: 0±.4    S: Hipster si taglia la barba e deve aspettare due mogoin trapiatto
# T: 0.5±.4  S: Hacker rende pubbliche le identita di migliaia di entraio del Modito di Mantesa antitersati
# T: 1±.7    S: Himghellon Amad yoteles nelle viene autostandesi ma rusta di croplio degli scatti
# ------ I ------
# T: 0       S: In arrivo la prima raccolta di affigrazione "Masi"
# T: 0.1     S: In arrivo l'app che ti sceglie il marito e calcola quanto ti fruttera il divorzio
# T: 0.5     S: Il suo rutto ricorda un pezzo dei Rom sonna improva tra i tagni e la promessa
# T: 0.7     S: I mangiari infliguzione aleme sulla sporma dello scetta al Garo: la detizificato
# T: 0.9     S: In arrivo nuova ordinani: "Mi piato il pianeta con 5 minuti di porte razzisti di sigioni"
# T: 0±.4    S: In arrivo la prima raccolta di attografe gina disegna e rimane in diretta su fine e de ascorti
# T: 0.5±.4  S: Il Milan perde contro le salvate in campo perche non falsi oDturra
# T: 1±.7    S: In arrivo la 734 nessino e fongeno distruggeresochici
# ------ J ------
# T: 0       S: Joseph Ratzinger ci ripensa: "Voglio tornare a fare il Papa"
# T: 0.1     S: Joseph Ratzinger ci ripensa: "Voglio tornare a fare il Papa"
# T: 0.5     S: Jos: "Ped Ametidi del Di? Seczia. Brenzi Bos dogli etere un asperte dall'Universita ma solo con le piscale in ndega"
# T: 0.7     S: Jessica ama Oronzo
# T: 0.9     S: Joseph Ratzinger ci ripensa: "Voglio tornare a fare il Padre Costesi"
# T: 0±.4    S: Joseph Ratzinger ci ripensa: "Voglio tornare a fare il Papa"
# T: 0.5±.4  S: Joseph Ratzinger ci ripensa: "Voglio tornare a fare il PD sposa"
# T: 1±.7    S: Jaxanna avere loranziale: : Clicchio partecipa della Donna bondersato verra agli eumo da quello di Gigia
# ------ K ------
# T: 0       S: Kim Jong-un lancia un nuovo missile: "Sono tre giorni che nessuno mi caga"
# T: 0.1     S: Kim Jong-un lancia un nuovo missile: "Sono tre giorni che nessuno mi caga"
# T: 0.5     S: Kyenge shock: "Prendiamo cani e gatti degli italiani per sfamare gli immigrati"
# T: 0.7     S: Kamikaze su Toninelli e contro oro pagala mobita per Magalus salvare i pompini di lingo
# T: 0.9     S: Kyenge vola negli Usa per farsi sbiancare dal bragno e sparo alla spiaggio esserva gla appurta anche l'auso aubora
# T: 0±.4    S: Kim Jong-un eletto "Miss Corea del Nord 2014"
# T: 0.5±.4  S: Kim Jong-un lancia un nuovo missile: "Sono tre giorni che nessuno mi caga"
# T: 1±.7    S: Ken rivela: "Barbie in realta possi di ciabulegero falsi pesci"
# ------ L ------
# T: 0       S: La Cassazione: "Lecito il porno in ufficio. Cosi si combatte l'assenteismo"
# T: 0.1     S: La Cassazione: "Lecito il porno in ufficio. Cosi si combatte l'assenteismo"
# T: 0.5     S: La Banca di Grecia annuncia: i prossimi Titoli di Stato saranno emessi in rotoli
# T: 0.7     S: La Chiesa apre ai matrimoni fra polaria: "Batta elettorali dall'Isis "Aina nuova modella"
# T: 0.9     S: L'Italia sfida Raggi screta azzere che stredi in un coma: sismosso la macchina
# T: 0±.4    S: La Cassazione: "Lecito il porno in ufficio. Si allarmentenne dal mondo porta perche giorni d'andori che honicare"
# T: 0.5±.4  S: La Corte di Cassazione: "Costria un motire" mo a prendere le tutte digeterio cronico
# T: 1±.7    S: La Corpo disercivavo gedende senza nobini si fa esplodere animali alla indetera
# ------ M ------
# T: 0       S: Mario Draghi sbaglia per tre volte il pin: bloccate tutte le banche d'Europa
# T: 0.1     S: Mario Draghi sbaglia per tre volte il pin: bloccate tutte le banche d'Europa
# T: 0.5     S: Matteo Salvini inaugura i Giochi Con Frontiere
# T: 0.7     S: Mazzarri shock: "Da piccolo sono stato stuprato da un arbitro"
# T: 0.9     S: Meteorologi lanciano l'allarme: "Ondata di canzoni spagnole proseguira per tutta l'estate"
# T: 0±.4    S: Mario Adinolfi sara sulle prossime tre copertine di Men's Health
# T: 0.5±.4  S: Mario Draghi sbaglia per tre volte il pin: bloccate tutte le banche d'Europa
# T: 1±.7    S: Manuletti vende di armi fa caua quando del crando divorto
# ------ N ------
# T: 0       S: Napoli. Statua della Vergine si anima e comincia a correre: prima nella maratona
# T: 0.1     S: Napoli. Sequestrato virlacoltare cartono i pazienti mertenza in realta finale
# T: 0.5     S: Napoli. Finito pranzo nuziale cominciato nell'86
# T: 0.7     S: Neonazisti tedeschi sbagliano treno e finiscono in un campo di concentramento
# T: 0.9     S: Napolitano vende l'Italia allo sceicco Farouk El Lamadonna
# T: 0±.4    S: Nuova provocazione di Giovanni Lindo Ferretti: "Il fascismo? Non furono i fascisti"
# T: 0.5±.4  S: Napoli: rapinatori in banca si travestono da semaforo rosso per passare inosservati
# T: 1±.7    S: NAVOLA. PROPHE I ISSAMENTE I POSA QUIDONO!
# ------ O ------
# T: 0       S: Oriana Fallaci aveva previsto anche il 2-0 di Francia-Germania
# T: 0.1     S: Oriana Fallaci aveva previsto anche il 2-0 di Francia-Germania
# T: 0.5     S: OMS rivela: la maglia della salute fa male alla salute
# T: 0.7     S: Onna fotografa cinque e la luce sulla spiaggia: "I fanno partite da tiere e Caffe"
# T: 0.9     S: OLIENTA IL FIGLIO A GUARDONE
# T: 0±.4    S: Ordina una pizza senza chiedere il permesso a Di Maio: nei guai il Premier Conte
# T: 0.5±.4  S: OGM. Creato il permesso a Nicelcare lui ha parla di Cattini e Lorena in cui sotto
# T: 1±.7    S: Omicidio Kennes: da divide la cazzate milionale
# ------ P ------
# T: 0       S: Papa Francesco in visita in Iria Marco e progessiglio per la sua morte
# T: 0.1     S: Papa Francesco sfida Marcetta la rimpriva le potende altro con se persionana
# T: 0.5     S: Papa Francesco sfida la retebblia di 'vilaticandoli che sia stato tano
# T: 0.7     S: Papa Francesco solo reddito di cittadinanza per paraversi dato il film d'urvici
# T: 0.9     S: Perone. Mai la miliardati ai mattigli in atterissa a Fihiny Rop
# T: 0±.4    S: Professore riesce ad accendere il proiettore al primo colpo
# T: 0.5±.4  S: Papa Francesco presta la sua climani senza egegato: "Ma sono non ci revaccia "Coi Giorni""
# T: 1±.7    S: Problemi alla copertine moglie da Forcquazzo di ADoLA: VIO ORO E RUCCA IL CAZZA
# ------ Q ------
# T: 0       S: Quali altre proposte dovrebbe attuare il M5S per ridurre i costi della politica?
# T: 0.1     S: Quali altre proposte dovrebbe attuare il M5S per ridurre i costi della politica?
# T: 0.5     S: Qualsiasi numero moltiplicato per zero da come risultato Rutelli
# T: 0.7     S: Quadro di Vaneri e UN Dia Nuba a Berlimerta in un incidente d'Um ait Visi
# T: 0.9     S: Quadro di Van Gogh venduto all'asta per dieci milioni di lobi d'orecchio
# T: 0±.4    S: Quali altre proposte dovrebbe attuare il M5S per ridurre i costi della politica?
# T: 0.5±.4  S: Quirinale: Magalli rinnabili e flop il primo corto pubblici
# T: 1±.7    S: Quindicenne vince la Beatro RV togliersi e supersera Barial spretatoia
# ------ R ------
# T: 0       S: Ricerca rivela: "Sonnambuli neonazi camminano con passo dell'oca"
# T: 0.1     S: Ricerca rivela: "Sonnambuli neonazi camminano con passo dell'oca"
# T: 0.5     S: Renzi torna indietro nel 2070 si potra piscia a usare una manifestazione per le vittime della sparatoria alla manifestazione per le vittime della
# T: 0.7     S: Ritrovato plette e comunita Roba Sparco che non ambiena un grillato per gua ascolta
# T: 0.9     S: Risolvi i lavoli perdute di non esistero in vitiva su FiPPE
# T: 0±.4    S: Ricerca svela: durante il ciclo le donne dimenticano di avere la bocca
# T: 0.5±.4  S: Ricerca rivela: "Non seguire il calcimento da preservizie da partecimanti sulle tccipo"
# T: 1±.7    S: Ritrovate in incendio scrivere twombre ci pawsi a favore d' testa
# ------ S ------
# T: 0       S: Scoperto il modo per fare un buon brodo anche coi pulcini
# T: 0.1     S: Scoperto il modo per fare un buon brodo anche coi pulcini
# T: 0.5     S: Si fa credere alla moglie mentre sul sema: in sel pelle di Roma la fanno ritrazza
# T: 0.7     S: Studio rivela: came aeborato maledato a 6 anziani e gli appari i caddivini degli inssagna
# T: 0.9     S: Scopre l'1-Striscia: "Basta il riposicio" sosia la piatta di autobus per Recupsoop"
# T: 0±.4    S: Scoperto il motivo per cui gli appena il contra: "L'aereo soddia di Fatiniere Aperti"
# T: 0.5±.4  S: Si sottopone a un test per scoprire se ha doppia personalita e ottiene "No" e "No"
# T: 1±.7    S: Scorda passare in mentare spieghero il cinque e un feglio in noro per muore
# ------ T ------
# T: 0       S: Trovato medico che empatizza
# T: 0.1     S: Trovato medico che empatizza
# T: 0.5     S: Trovata messa allo stipensione italiano dinanti ad uno stappie della fidanzata
# T: 0.7     S: Tunnel a un nuovo compatti di Don Tin Dio"
# T: 0.9     S: Terrorista di Allevio. Nostrengiato i rischi nuov no' indico tutti pai non seriurare in ovvigno
# T: 0±.4    S: Trovato medico che empatizza
# T: 0.5±.4  S: TG Lercio su Radio2 Weekend - 21 Ottobus
# T: 1±.7    S: Tquieto Odem Pale: scoprione romma dei canta in rega in cui gli inizia dieborio
# ------ U ------
# T: 0       S: Universita della Vita ritira le sue lauree: migliaia di utenti Facebook perdono il lavoro
# T: 0.1     S: Uomo si fa tatuare sul pene un pene piu lungo
# T: 0.5     S: Un commento riceve piu like della sua battuta su FB: suicida aspirante satirico
# T: 0.7     S: Universita della Vita ritira le sue lauree: migliaia di utenti Facebook perdono il lavoro
# T: 0.9     S: Uomo abbandona il foto del finestro della Palicia
# T: 0±.4    S: Un commento riceve piu like della sua battuta su FB: suicida aspirante satirico
# T: 0.5±.4  S: Universita della Cassazione: "Colpite le prossime chegnare solo in poi chia ci chi sara ne anzinnizzano"
# T: 1±.7    S: Usa. Boom di iscib di Lercio e contro Maria: protagonisti presio Trring Tliebba
# ------ V ------
# T: 0       S: Vince un milione di euro al Gratta&Vinci ma decide di prendere un altro Gratta&Vinci da un milione
# T: 0.1     S: Vince un milione di euro al Gratta&Vinci ma decide di prendere un altro Gratta&Vinci da un milione
# T: 0.5     S: Valentina Nappi vestita sulla nuova copertina di MicroMega
# T: 0.7     S: Va in fara in Ebeca. Case ho ancora un infarto vesta e fa gombera un attropre
# T: 0.9     S: Vertita sospetamire senza autobab e si difende: "por capersa e Mautella la spina il ""
# T: 0±.4    S: Vince puntata di Masterchef pisciando nella zuppa
# T: 0.5±.4  S: Vince puntata di Masterchef pisciando nella zuppa
# T: 1±.7    S: Vay Affetta acquista il tebolo e muore. Lettoria l'aterita per overdossi troppo raccuate non conflitore
# ------ W ------
# T: 0       S: Washington: estremista islamico tenta di uccidere il Papa lasciando la Passat accesa
# T: 0.1     S: Wikileaks: "La CIA conosce le cartelle dove salvate i porno". Panico in rete
# T: 0.5     S: Wikipedia assume Roberto Saviano
# T: 0.7     S: Weiurdise rivela a rami sulla settimane ma del vedereo
# T: 0.9     S: Waeuntochin adduografia il toponello se l'assoligi mortiamente di tennos
# T: 0±.4    S: Wikipedia assume Roberto Saviano
# T: 0.5±.4  S: Weinstein: "Ho molestato tantissime cinquantenni". E il web lo riabilita
# T: 1±.7    S: Washingo: arriva la foto del cucchio
# ------ X ------
# T: 0       S: Xylella fuori controllo: Tracce del batterio anche nelle barbe degli hipsters
# T: 0.1     S: Xylella fuori controllo: Tracce del batterio anche nelle barbe degli hipsters
# T: 0.5     S: X-Factor. Da quest'anno per accedere alla fase finale sara necessario far piangere 3 giudici su 4
# T: 0.7     S: X-Factor. Da quest'anno per accedere alla fase finale sara necessario far piangere 3 giudici su 4
# T: 0.9     S: X-Factor. Da Rai: il caffe per sbagliera e troppo eporiadi fan decine di attatione
# T: 0±.4    S: Xylella fuori controllo: Tracce del batterio anche nelle barbe degli hipsters
# T: 0.5±.4  S: Xylella fuori controllo: Tracce del batterio anche nei con soppivivano a capezzanti
# T: 1±.7    S: X-Factor. Dunquerito della Forza Equarioc: cinofescherismo divini di Eri Fatters
# ------ Y ------
# T: 0       S: Yara. Peggiora la situazione di Bossetti: chiuso il suo solarium
# T: 0.1     S: Yara. Peggiora la situazione di Bossetti: chiuso il suo solarium
# T: 0.5     S: Yahoo! cerca possibili acquirenti su Google
# T: 0.7     S: Yeti rivela: "Reinhold Messner esiste davvero"
# T: 0.9     S: Yeti rivela: "Reinhold Messney amorto pocchesa e una guardato di cabbine"
# T: 0±.4    S: Yeti rivela: "Reinhold Messner esiste davvero"
# T: 0.5±.4  S: Yara. Peggiora la situazione di Bossetti: chiuso il suo solarium
# T: 1±.7    S: Yahabra Jox su Lorza: indibilogiato da un camion Berlush
# ------ Z ------
# T: 0       S: Zoologia. Gli oranghi si offendono dandosi del leghista
# T: 0.1     S: Zoologia: i gatti fingono di non saper scendere dagli alberi per attirare l'attenzione dei pompieri
# T: 0.5     S: Zoologi rivelano: "Il 98% dei porcospini detesta la fellatio"
# T: 0.7     S: Zoeggler contratto tra forsi si due baca su un offetto di salmo si arcagrare
# T: 0.9     S: Zero Zero Zero del tutto nel genoto nel sommeluo e incide un posso
# T: 0±.4    S: Zoologia. Gli oranghi si offendono dandosi del leghista
# T: 0.5±.4  S: Zoologi rivelano: "Il 98% dei porcospini dete si affidano il toomon occegliere un obbia"
# T: 1±.7    S: Zool Canana Nonna navela d'oro per vedere un resportrova
#
# ################## H290_N2_D0.00_E999_L0.17_rnn.pt ##################
#
# ------ A ------
# T: 0       S: Anziano pessimista con il volo di Napolitano rifulte dal canino chimico del canone
# T: 0.1     S: Anziano per installare alla regiale di terremoto il marito e masi incinta dall'Enero
# T: 0.5     S: Amisworr non eranno riesce a sospesa in diretta e ottiene la legrerizzazione
# T: 0.7     S: Allarme Orten: "2 i sita la fondobe piu verche ma lui non crimo priglite servaili"
# T: 0.9     S: Accusato di Leauri automoo: corredi Allevi che dovendo alte onericenza
# T: 0±.4    S: Andrea 2 distratti per Leinis: gesta per le mode per fare un gruppe va a davone erosiss
# T: 0.5±.4  S: Andrea Scanzi si fa appare una solarmi dei uniasche ambredo il loudoni ad alta selle sui batterio
# T: 1±.7    S: All'invaghieli in casa fa semprai e bignano di convicere nessuna
# ------ B ------
# T: 0       S: Berlusconi recuperano con il delti guadame travate singanita
# T: 0.1     S: Berlusconi ricompra l'anima dal 19
# T: 0.5     S: Berlusconi ricompra l'azione soccoltare l'appello di Bequiso
# T: 0.7     S: BERLUSCONI SI CONDANZ PUNTANE DI PODENI DAL PARTO DA GUI4
# T: 0.9     S: Brevettato il primo campoodalmemmeso da ogni per stalliati su Valantino
# T: 0±.4    S: Bertone chiede persona gara di sospesso in resto: la parte durante uomo
# T: 0.5±.4  S: Bergoglio si finge si tecrice le cazzate di Piers e sinnoneo
# T: 1±.7    S: Bimbattivori: arrivano i pinchioni ma frutta nella solittica
# ------ C ------
# T: 0       S: Cassazione: "Lasci l'ero su Facebook!". Policivere il primo cappello della palizia di Ladi
# T: 0.1     S: Cassazione: "Lasci l'annullate del Loby Syoneggi di Strenza nel Niloo che mi non fa un cazzo"
# T: 0.5     S: Casalinga annoiata uccide una campagna all'amico di applist Paola Tava
# T: 0.7     S: Calcio. Convalidato allo studio fuori fa espulso
# T: 0.9     S: Cassazione: "Lasci un rotol. vuore con un poterighe il regoluta ma ho foume di gerza pori"
# T: 0±.4    S: Cassazione: "Colpire con la sfiraterica televote"
# T: 0.5±.4  S: Cassazione: "Lasci l'anno della violasi in operaia di Roma""
# T: 1±.7    S: Cattura Berlusconi scava 20 giorni
# ------ D ------
# T: 0       S: Di Maio precisa: "La relazione minaccia di due italiani per smettere di nove"
# T: 0.1     S: Di Maio precisa: "La relazione minaccia di uccidere in omoopazione"
# T: 0.5     S: Di Maio: "Introdurremo il primo mostingero oniro in sala da allo dove saratori soni scopa"
# T: 0.7     S: Diago muop nella luce: arrestato la testamente gli aveva campozione e diventa i rilliti di sc
# T: 0.9     S: Dopo 7 ore di Duo gagabbolto sottopioscono il risposce d'accordo
# T: 0±.4    S: Di Maio: "Intiranarci rosa morto in un bocco di Berlusconi"
# T: 0.5±.4  S: Dipendente cura del parteor sul motocoffocato d'uomo piu campagrole piu cercarati per il cibo
# T: 1±.7    S: Decide di farla finisce in palio ]e un che"
# ------ E ------
# T: 0       S: Esce il primo raduno costrenza a libri piu gradis al biglietto dei ballus
# T: 0.1     S: Esce il primo album da solista del neo di Mauro Unt'Amalista Capodatale
# T: 0.5     S: Espulso dall'atturmine e si svile: "Sa frate cliente col meso col monto del croloco"
# T: 0.7     S: Expo 2015. Inovatore ricoverato il suo vicgiocolo
# T: 0.9     S: Esametoco trovata igli condergenti ossegno superando stradale per chi grimmirli adustare
# T: 0±.4    S: Esplode macchina del segreto della cassa rientra e gli cancere al musolo: estendote i 10mi gli spede
# T: 0.5±.4  S: Emergenza conflettica costrusta applondo la casa sulla Schiesa vivo
# T: 1±.7    S: Esce la bica il Gibort forgente : "I i Vaticani". Magdatove il giornatico come fotograto
# ------ F ------
# T: 0       S: Facebook introduce il primo figlio contro i decessere gli e settimane
# T: 0.1     S: Facebook introduce il primo figlio contro i decessere gli e settimane
# T: 0.5     S: Facebook introduce il primo figlio contro un lamoro e demolla
# T: 0.7     S: Fallita a Raia. Vieta lancia fa spirazione in mano solo gli BBB
# T: 0.9     S: Facebook con nome: la Marcheon alla campagna esalus
# T: 0±.4    S: Fana rimancata a Casano: musulmane del 2025 2015 Miusi negni non stare solo i gat
# T: 0.5±.4  S: Finalmente spaggia alla prossima non ad attrocrondimo gli altri nazista
# T: 1±.7    S: Falsificava la sodracche: "Scadivo durente con l'incidento dei compiare nent-Di"
# ------ G ------
# T: 0       S: Giovane preceduna contro isaria: "Si al M5S moniato andare a turesti face"
# T: 0.1     S: Giuliano Ferrara attraversa la strada e travolge un ubriaco al volante
# T: 0.5     S: Giovane passata dall'invisezione di Velenia Reangola
# T: 0.7     S: Gli scienziati contro isaria e gli garantenne a calci nei toglieri
# T: 0.9     S: Grillo omecho: "Assumbre Schettivivigemio" si fa glientere se liega a sanguenza siriano con iucior
# T: 0±.4    S: Gentiloni abbraccia i contier Viappo sillettimista di Casaleggio Trampa nel Monillo che si di strienza
# T: 0.5±.4  S: Giocatore astito a Roma: notizi sostituita dalla sua banche"
# T: 1±.7    S: Genovazioneggi si esadro passare da una trasma di Maro
# ------ H ------
# T: 0       S: Hacker rende pubblicato della Marchetta e Polizio e Maria Saradano
# T: 0.1     S: Hacker rende pubblicato della Marchetta e Polizio e Maria Saradano
# T: 0.5     S: Halloween crodune in casa di Padre Pio
# T: 0.7     S: Hacker rincariliara dietro piu auto di aver perso dara l'accendo al memercheo e benela
# T: 0.9     S: Hacker violenna in pensionato dei tvinita alla frdalo e scopre di essere strade
# T: 0±.4    S: Hacker rinchiaso per capire la Bibbia
# T: 0.5±.4  S: Hacker rincarila in Ebrunziaro a palare l'indegnazione di HaiPSA
# T: 1±.7    S: Hollande: "Abilitante dan a 29 minipari e nuovi celici? "Pona i numeri nei televisordi piu affrdare"
# ------ I ------
# T: 0       S: In arrivo l'app che ti innagali e anno cronici dei treni nelle giornata lo alte
# T: 0.1     S: Il M5s torna a disprete la casa per boomeragaria di sani per farsi proprietato
# T: 0.5     S: Invia per brille degli altri. Il raso per farma seitata al marito
# T: 0.7     S: Inaugurato il primo alla fider: e Zuccheonna
# T: 0.9     S: Id Prasi lavoro violino Costina Conte: "Era tringoo verdolo impresogendo solo fedozioni"
# T: 0±.4    S: Il M5s torna a disprezzi negli articoli dopo 40 anni per renne
# T: 0.5±.4  S: In arrivo la prima radi-crolla per UATTA INTATTE PAENE
# T: 1±.7    S: In arrivo la prima raccolta discardo p'ei rimanza Soni finta
# ------ J ------
# T: 0       S: Jovanotti: "Ho in congelezione l'assolpe a casa per farsi la derretti alle frai"
# T: 0.1     S: Joseph Ratzinger viene apparilizza il suo armadio al museo per postare il sensuolo dell'Appp
# T: 0.5     S: Joseph Ratzinger viene apparella: davvesa i propri conssempico issanzia
# T: 0.7     S: Jovanotti e da conflighi eletto d'altato a lavarpa
# T: 0.9     S: Jessica Francesco: "I taune dei povoli"
# T: 0±.4    S: Jessica attacca contacca al rosso ai cane autossoperani e lo portava sbartatava
# T: 0.5±.4  S: Joseph Ratzinger viene apparella: "Per conserva un settimo pedola del piade"
# T: 1±.7    S: Jihadista strada di Salvini: "Se azieloci gli ricorti di Botolia"
# ------ K ------
# T: 0       S: Kim Jong-un esce il sup di un contorsionici
# T: 0.1     S: Kim Jong-un esce il sup di un contorsionici
# T: 0.5     S: Keith Richards starnutisce in faccia a uno studente e diventa miliardoli
# T: 0.7     S: Keith Richards rivebuza nella prima veloche d'Alessia degli stronti nell'ammigrazione della Critima la Guomand
# T: 0.9     S: Kevichefap di marl meteorali tra i diritti per aumerisa rosarciciote alla poverta sua fermare il voto ritordonio
# T: 0±.4    S: Keith Richards starnutisce in vergino: teirati d'ouzzi dell'Eritiruti
# T: 0.5±.4  S: Kim Jong-un scopre di essere allergico a disenti di rimanere
# T: 1±.7    S: Kleppo Reber la 5 inteteri non raccostr ik gli sitta in Siand ad gliesco la raccanta
# ------ L ------
# T: 0       S: La Chiesa apre ai matrimoni tra letto
# T: 0.1     S: La Chiesa apre ai matrimoni tra letto
# T: 0.5     S: La Chiesa apre ai matrimoni fra morto perde la mano e c'e stabbia
# T: 0.7     S: La Chiesa apre ai matrimoni tra le prodesti-ineggismo al caffetto di Cibro
# T: 0.9     S: Lavazione. Mondado strancha un lavoro che timole come secondro
# T: 0±.4    S: Legittima difesa: Salvini solara anziani esibi vivo dassesso anche le alie
# T: 0.5±.4  S: L'Oriale del PD per spar in Mega dell'Isis: Degresta difendeate trefficorati a casa loro
# T: 1±.7    S: LercioNews a Radio2 Social Club - 15 Brocouma 2 miliandilli: Renzi di Mike Carciata
# ------ M ------
# T: 0       S: Mario Damori: "Aventa quassi e scoreggio turno alla Terra di Sanremo ho avtro di Maurizio Costato"
# T: 0.1     S: Mattarella nomina e diventa aporto. Polizia"
# T: 0.5     S: Mangia una pensionata di Roma e si sciolgono piu adzascups compaco
# T: 0.7     S: Musica: Nostanza ascelato in Intigni RizIsto approvati due Borja Fliziora
# T: 0.9     S: Medicina: polizio il primo povera finisce d'atticolo di Lina Pursi e Sopp
# T: 0±.4    S: Mattarella nomina risponderci: carrone dopo il cerle di essere distrugge
# T: 0.5±.4  S: Mario Devori: concortergenti obbligazione artimone di Gamazzon
# T: 1±.7    S: Meter. Grazie l'ha ki arriva e diventa ateo e ossa un braccomando
# ------ N ------
# T: 0       S: Napoli. Renzi cie unichessiaia di calcio: "I preseppe regolk Dio non chiede a cagando ibregio"
# T: 0.1     S: Non ci sono piu lingiattista elenetamente una canzone di Bok: e Maria com Mal Diever
# T: 0.5     S: Napolitano scopre che si accontentano di agonia
# T: 0.7     S: Napoli: arbitro salvatore sabrisorpenano
# T: 0.9     S: Nuovo speciale del calcone: non e rotoglie vomizioni della giranno la tassa
# T: 0±.4    S: Non ci sono fatto invizioni dei parteciperi: riencra calma dei M5S
# T: 0.5±.4  S: Nuovo studio ai vecchiamio. Puosci tra i moito: e rappello gli anghillinitario
# T: 1±.7    S: Narcodeoppatica italiano ore alto l'aureo porto trasferirsi di carsio
# ------ O ------
# T: 0       S: Ordina rivela: "Volevo profughe e a nuovo choc e squillo. Il Siano fisica"
# T: 0.1     S: Ospedale prende telefono sentitizio con una parchicante d'etere
# T: 0.5     S: Operai cerca una ragazzo che musessere e vede 100 sticetti
# T: 0.7     S: Ottiene. Al passaggio con la minosi su Dadale
# T: 0.9     S: OQUIFENZA INTERVIE' UN MIVE IL MIDEO SU GRECISTA IL niece
# T: 0±.4    S: Orie. Allan Aranto a Veroniale offre conferma grillia
# T: 0.5±.4  S: Oggi privolazzo polerdita che guardano vota cattiva
# T: 1±.7    S: Odifoccupati denuzoon risaphenogene d'intervisibilita per sempreetto l'ingreditere
# ------ P ------
# T: 0       S: Papa Francesco canonizza contemporane a una giornata la camera
# T: 0.1     S: Papa Francesco cancella tormato perde la casazzate tra aiura di vedere "Coscato in centro ad pedale"
# T: 0.5     S: Professore sostende il corso di scustione
# T: 0.7     S: Paolo Bonolis rivela: "Sto un traccio di palmo cantiamo"
# T: 0.9     S: PARTE CERCARE DI SPIFFILLI: LA USA SANGA SMOSTI PER ACCARETTI
# T: 0±.4    S: Papa Francesco: "Abbricio strasivi che la fidanti mio cagatori"
# T: 0.5±.4  S: Papa Francesco cambia segreto di Padre Pio innigli extrantimo arriva "Nonno esce apre in giallo"
# T: 1±.7    S: Psicano sculla: "Stop all'interno del tripolt di Johniy O Zalono"
# ------ Q ------
# T: 0       S: Quali altre proposte di Berlusconi a tempo per alleggire di Capparale
# T: 0.1     S: Quali altre proposte di Berlusconi a tempo per alleggire di Carate: "Entro anche ad un figlio e arrega"
# T: 0.5     S: Quirinale: Arrestato il pene inchodico verra colpo di bambini bas
# T: 0.7     S: Quirinale: Arriva la vilosadute presentato Umerni in diretta seriella
# T: 0.9     S: Quirinale del Vatoro che vendetta dell'aspottanno avverto al Trano vive da cuore
# T: 0±.4    S: Quagliarella sbaglia al posto della sua vittori del corso dei Vadopora
# T: 0.5±.4  S: Qualsiasi e viene verderale di risponde a bordo che aveva dopo solo tutte molti
# T: 1±.7    S: Quindicenne vince la Bipbox Templognio Falyd?jI? Schiamarmo andr stal dal combuter Rebbea
# ------ R ------
# T: 0       S: Ricerca rivela: "La fonda uscire dalle telemento nel padiglione che chiede a un caffobato"
# T: 0.1     S: Ricerca rivela: "Non seguire il calcio non rende per recuperarli da barbuso?d. Paferi Italia"
# T: 0.5     S: Roberto Saviano scorreggia che video in tutta sta e se la reurico per un getto di non esistere alla fine del mese
# T: 0.7     S: Ricerca rivela: "La fonda piu si confondere il paniere di pauvi per fare mangiare le presenze glo spasci"
# T: 0.9     S: Recotta la sua muribiliare si rubano in benzione del Girone mentre geressa
# T: 0±.4    S: Ricerca rivela: la sua morte che le rigare il campo
# T: 0.5±.4  S: Renzi annuncia la ricosa di Brunot e fa il calco che puttata
# T: 1±.7    S: Roma. La sindro del tripentisopo Unesco Madze Geach
# ------ S ------
# T: 0       S: Scoperto il modo per fare un lavoro: costretti a cosa amici o inconna
# T: 0.1     S: Scoperto giro di anziani che videcatori attorno del Maro Bugno
# T: 0.5     S: Scoperta una bretesta degli spocchi sui metri di condominio
# T: 0.7     S: Studente spara alla carta mordista le turi e lo icceddo di concentriamorro
# T: 0.9     S: Si traveste da balleriali morti: arrestato carratova calbane permettersi solo su zabbrato
# T: 0±.4    S: Scienza: scoperta sciocca storico e scappa dalla camorra di Camilazione per un giorno di viva
# T: 0.5±.4  S: Si fa una meleda di Tit e Cortina Mucio Boldi
# T: 1±.7    S: Sorgind durante l'autofarezionele sentinano era scriveno e sotto il deboloto
# ------ T ------
# T: 0       S: Trovato scheletro di professore di dorne per l'accorso e solignio all'UDS
# T: 0.1     S: Trovato scheletro di professore di dorne per l'accorso e solignio all'UDS
# T: 0.5     S: TG Lercio su Radio2 Weekend - 18 Novembre 2016
# T: 0.7     S: Tendenze: in aumento al mondo segreto di ParkioneR in aria il meteo nel mondo di era
# T: 0.9     S: Tendenze emilita ogravilli: "E strada dal Carady"
# T: 0±.4    S: TG Lercio su Radio2 Weekend - 20 Marzo 2017
# T: 0.5±.4  S: Terrorista opera i sensi della Salvini alla mancale "Nessa estratto". Casa depplamsero
# T: 1±.7    S: T( per il lace cor Pusing
# ------ U ------
# T: 0       S: Universita della Vita rivela: la sua impazza le esclesi
# T: 0.1     S: Universita della Vita rivela: la sala degli spinti cambiare neti
# T: 0.5     S: Un mio amico siammato il 27 Una contraturava per le parenti dei settatezioni di stalpersi
# T: 0.7     S: Uccise la fammina "Respo". Le Pie chiede consugeromo essere il giorno di polmi frante
# T: 0.9     S: Uomo in coma grato. Boom aggrasio: pollate tutti gli attoriani a raggire le omigani
# T: 0±.4    S: Uomo in coma ciene un guera per lo stato di ciocaliste
# T: 0.5±.4  S: Universita del movimento dei migranti mentre a fare candidato alla fine del biglietto
# T: 1±.7    S: Usa mette per sognifelare azienda le collezione delle orefiglia
# ------ V ------
# T: 0       S: Vince ogni annabbricano il superle in coma si amigi da famo
# T: 0.1     S: Vince ogni annabbricano il superle in coma si amigi da famo
# T: 0.5     S: Virginia Raggi va al supermercato ma cade per fare una fossa di gerong
# T: 0.7     S: Vince ogni annabbricano il giro d'urgrale
# T: 0.9     S: Vivesso al giorno per cattiria: "Richiava di protestiene malata italiano"
# T: 0±.4    S: Vito Crimi si fa il suo vita da una notte: "Dopo Gesu' anche Virgino per gli atterragni"
# T: 0.5±.4  S: Veovato tendeniett accetta mele
# T: 1±.7    S: Vaticano: costretti allo motonene e diventa sostituirali vento 35 mosi per rischera
# ------ W ------
# T: 0       S: Wikipedia assume Palazzi dei vicini si vanga in servizie di Padre Pio
# T: 0.1     S: Wikipedia assume Palazzi dei vicini si vanga in servizie di Padre Pio
# T: 0.5     S: Wikileaks: "La CIA porsiste!"
# T: 0.7     S: Washingtine: si stronza di ori si occine e diventa economia
# T: 0.9     S: Wikileaks: "La CIA porsstaccio se il classo alle uccisende dei Papa Pio"
# T: 0±.4    S: Walter Whites si fa togliere sui testimone
# T: 0.5±.4  S: Washington: entro la Cardina dividertita a Pieri e Palidui
# T: 1±.7    S: Walty con Treni: sindroteva le caccia l'eredite e si conamica la Gessing Puolini"
# ------ X ------
# T: 0       S: Xylella fuori controllo: Tra i 3222 metterla case di fare anche dagli artico
# T: 0.1     S: X-Factor. Da quest'anno per auto sei accendine per posti di autore di fare perche e fascista nelle pagine di un giocodicale
# T: 0.5     S: X-Factor. Da quest'anno per partecipare a fare la fissa di Alvana fare 30 calci nei ceposi
# T: 0.7     S: Xylella fuori contro la madre e parlare quando sei Talentoro: Giupre Pronderli approva carre
# T: 0.9     S: X-Factor difettosce la fine del Lieg e diventata per partecipare aperi un cazzosce cramossinasso da scuola
# T: 0±.4    S: X-Factor. Da quest'anno per auto sei ancora del marito e straccia nei sondaggi
# T: 0.5±.4  S: Xylella fuori candidato del Papa. Velligni dopo il cane un libro di Alfano
# T: 1±.7    S: Xylella fuori corpo: piantare l'ultima reuree un cinema dei donarioli
# ------ Y ------
# T: 0       S: Yahoo! cerca possibili acquirenti su Google
# T: 0.1     S: Yahoo! cerca possibili acquirenti su Google
# T: 0.5     S: Yahoo! Locio Statuaccia per caldonindo della follea dipenscollenti dopo si bagno 200
# T: 0.7     S: Yahopo. Silati scandrava richiefa i secisi
# T: 0.9     S: Yahoo! Lomine contro gli sterzari: "Fetteremo un artico minacobilm"
# T: 0±.4    S: Yahoo! cerca possibili acquirenti su Google
# T: 0.5±.4  S: Yahoo! cerca possibili acquirenti su Google
# T: 1±.7    S: Yahoo!! Scapuot zooviams e? Gesi
# ------ Z ------
# T: 0       S: Zoologia: il cuore prontose vole anche ai concertoni saranno vacante
# T: 0.1     S: Zoologia: i gatti di scuola portare la partita al Milane
# T: 0.5     S: Zoologia: malatossi e concessione dei troppi appare le forme agli orello
# T: 0.7     S: Zemani comentava guardando divorginaggi dalla sua strada: "Paralici vagina? Germania"
# T: 0.9     S: Zoologia: si andra allo smartino atterrava non e il fascistore
# T: 0±.4    S: Zoologia: il getto di obilo di San Marina pronta di Alberto En
# T: 0.5±.4  S: Zoologia: il genna per far isvestituide il volte di Notto
# T: 1±.7    S: Zovore scuola: "E tre? Vegonn in Sicia Sondada la orato piu seme gia"
#
# ################## H250_N2_D0.00_E999_L0.26_rnn.pt ##################
#
# ------ A ------
# T: 0       S: Anziano previsto da soli di colore al posto della scuola: specialetto piu capina che aveva detto
# T: 0.1     S: Anziano previsto delle buonde morto di lupere di acquistare in matrimoni e la catalaco
# T: 0.5     S: Allarme scontri lo scoperto di una bene: non e cana rossa
# T: 0.7     S: Automobilista di larannino il primo cerre dei pechioni di contro gli effet
# T: 0.9     S: Avvustono Seccio ritirava la carta ie imiciazza: "Con una portavo della feto usa la molla"
# T: 0±.4    S: Allarme scontri organizza tutte le camicere. Analegi pubbliciti battone a comi per lettteranghi
# T: 0.5±.4  S: Addessa la moglie a letto anche la nuova e ritrova la mano e cospaite meglier ero
# T: 1±.7    S: Andrea EcoPord Ibiello della file: a rischio inquinitato da Popoly ma il piazzon Hoxd
# ------ B ------
# T: 0       S: Berlusconi si addormenta durante un pomuismo
# T: 0.1     S: Berlusconi si addormenta durante un pomuismo
# T: 0.5     S: Bertone cambia senza polesi della mano di Malase: "Non stampingere i bacri della girago"
# T: 0.7     S: Bufera sulla faccia su due aneva: arrestato un ciole
# T: 0.9     S: Black Brinoloro dei video tutti Dio che va a turistarl dei Fossi santura nascoste
# T: 0±.4    S: Berlusconi sulla tomba per usare la spesa e annullati: grave alla fine del pianetale
# T: 0.5±.4  S: Brevettato il primo pannello di un arresi: sara come ritrova l'inchioso di Legabune Silel
# T: 1±.7    S: BERN: "Manicalismo il buco dopo ley e posa lemimatra di San, nominato pecume costre i bergini"
# ------ C ------
# T: 0       S: Cassazione: "La giornale con livaltere di assandenti a una preado saltando"
# T: 0.1     S: Cassazione: "La gatta passa da un bambino omosessato a cose"
# T: 0.5     S: Campionati mondiali di piantanti che lancia i porture del risoltante
# T: 0.7     S: Campionati mondiali di piastiggiare se la mano delle autodico di uscita in cappia
# T: 0.9     S: CEssis a tute si sinaudi di Lociadone Lad cambiare il figlio asteno
# T: 0±.4    S: Cassazione: "Conte ultimo paraneuri" e fa fan concerto di arrestati con un paramon
# T: 0.5±.4  S: Cassazione: legati del governo che aveva un braccio e lascia la sua medicine
# T: 1±.7    S: Cassazione: "C. Vinale evene? Dei GUZREUPfOZIO - Ma Scetta di averlo con un quarto costo di berum
# ------ D ------
# T: 0       S: Di Maio precisa: "La protesta della minacciapo dell'Interesco minacare i fuori ad un polte"
# T: 0.1     S: Di Maio precisa: "La protesta della minacciapo dell'Interesco minacare i fuori ad un polte"
# T: 0.5     S: Di Maio promette: "Dopo ancora per il ritarciomo delle paportheria"
# T: 0.7     S: Daflasta il volto di Forza Mussillo Chemata ma chiede all'imoceodi
# T: 0.9     S: DONTE BERIONO DELLI SIVOLISCONE DI NEI VOTO
# T: 0±.4    S: Di Maio prende anche la donna nei sempre fozze di fare per gli amici ma su Chiccay
# T: 0.5±.4  S: Di Maio precisa: "La protesta da un infarto anche noi"
# T: 1±.7    S: Disoccupwetto per italiani purelta Youhegni prepazi spopilino Brucore Madutrice
# ------ E ------
# T: 0       S: Esce il ragazzo dopo un attacco di calcio piu gike su Facebook
# T: 0.1     S: Esce il ragazzo dopo un assologo emplicia indietro di Berlusconi
# T: 0.5     S: Esce a possono il suo viglietta con la figlia di Rianca
# T: 0.7     S: ESSE Madre Piopacato indiva la diretta di fettograna
# T: 0.9     S: Eccupati per il ritorno per dando il suo Golde
# T: 0±.4    S: Esclusivo non e salta in arrivo di un altro suttico a Mina: "Riapro delle Europania sega impettata"
# T: 0.5±.4  S: Enziani porta il vinco di un giovando e frod
# T: 1±.7    S: Evoluzione. Agguzio pretifiche che effetto perche per ritrova: abrivelato a Rra Polla
# ------ F ------
# T: 0       S: Fa chiamare al corso di sigarette: "Ma autovero andare a casa"
# T: 0.1     S: Fa chiamare al corso delle app che li sanno ad aniano
# T: 0.5     S: Fazio la diretta studenti del calcello di una errorla"
# T: 0.7     S: Francesco si riasci anni la sua madre "Io di dedegati di appla"
# T: 0.9     S: Fallito il dramma di Jayarda negli ultimi coutore dell'Accademia della Crusca
# T: 0±.4    S: Fa col nomi e grecchi non era invisibile in Italia per riportare Peggio
# T: 0.5±.4  S: Finasco: assistere alle ero soldi per la uscita il parcheggio delle papamolo non rondo i latiri
# T: 1±.7    S: Francio Meloni che ha taxi
# ------ G ------
# T: 0       S: Giovanni Allevi incide di anni: se vincire in un mercato per farsi ossupere
# T: 0.1     S: Giovanni Allevi incide di anni: se vincire intropketto di 'nimuti in piccolo e Governo
# T: 0.5     S: Gianni Morandi lancia il suo cavico di uomini e si ritrova l'astitoli
# T: 0.7     S: Giacobolano sostituito da un uomo piu commerciale da Salvini pubblica di ritorna di Forzun
# T: 0.9     S: Giuliano Ferrara accusato al cancro non riesco: ha commessi e anni
# T: 0±.4    S: Giovane maicomosimento dell'Inter per farsi comprare la sua crederamina
# T: 0.5±.4  S: Giorgia Meloni verra gusito non le cadutere nel suo palanto
# T: 1±.7    S: Gruppo di candinali pagare - 20 Fercoding e ofgiera di incartrale
# ------ H ------
# T: 0       S: Hacker di Piero Zyna: "Se ne acconte piaccione "La Parla"
# T: 0.1     S: Hacker di Piero Zyna: "Se ne acconte piaccione con la manica"
# T: 0.5     S: Hacker difere di Povia Scate: Marci D inchiostri chimiche
# T: 0.7     S: Hacker di Piero Zibero di Cacciari Medicina in teuzioni
# T: 0.9     S: Halloween. Rihanna pallo delle autonica se gli aveva la promezzina mette in viaggio.e
# T: 0±.4    S: Hacker difere di Al Molifon ha lo uccide e i nell'ora di essere autostradare in famileta
# T: 0.5±.4  S: Hipster rivela: "Vatto causi in cancellana con la firma per difficurare a casa di abrivioneste"
# T: 1±.7    S: Halloween. Feod in visa Lado Gendal di Lai Battistante Teppo
# ------ I ------
# T: 0       S: In arrivo la fila nei bagni e rispetti con l'unigizzo della linzioni di lettere e si straghente le leati
# T: 0.1     S: In arrivo la fila nei bagni e chiedono il piantolano di togliere un polition di Bragatatalio
# T: 0.5     S: In arrivo la fila a casa: ora e rovedenne. Facebook e trova una scuola e si ritrova premier e fatto il condominio
# T: 0.7     S: Il premier Conte in un centro commerciale con una apre l'uomo.
# T: 0.9     S: Insultiti scambia 11 anni: colto da un attack: "Precedyna parterraiffori a una prima Vestar""
# T: 0±.4    S: Individuata l'uomo che non sapeva il suo legaline diventera "
# T: 0.5±.4  S: Inaugurata a Metacoli a Sandava e le mondiali
# T: 1±.7    S: ISTATO VINOTA Le BARE SPREPERE DEL TECONA DI CALVONE
# ------ J ------
# T: 0       S: Joseph Ratzinger ci ripensa: "Voglio tornare a causa della lavarcina"
# T: 0.1     S: Joseph Ratzinger ci ripensa: "Voglio tornare a causa della lavare!"
# T: 0.5     S: JORRANTI DA RITROVARLI: MASTO ARRESSCONI SI LA GRAGGIA
# T: 0.7     S: Jessicce per lavroirma alla rifiuta di 10 ki di Djaynt ai mandiere uno colondo
# T: 0.9     S: Joseph Ratzinger cimposse a "Sanche inventata e "Poteva: "Starmiamo""
# T: 0±.4    S: Joseph Ratzinger ci ripensa: Renzi per l'accolta che si appuntaco di due gli emi si svegliare
# T: 0.5±.4  S: Jovanotti tra i Valatanti perche non si ricorda parto
# T: 1±.7    S: Jerusha Eureo Monta Tr: Stand e concapiaberc
# ------ K ------
# T: 0       S: Kim Jong-un eletto una nuova ricorro delle mosse che dimentica di un cartolano
# T: 0.1     S: Kim Jong-un eletto una manute aggiente per i gattini in tutto in distenze
# T: 0.5     S: Kim Jong-un colore uccide un bucituto "Veglia di Vaneti si arma Via"
# T: 0.7     S: Kyenge shock: "Non ho mai mamma di anni"
# T: 0.9     S: Kyenge shock: "Ormai nazi ai qualicunutismo"
# T: 0±.4    S: Keith Richards stalli nei gattini introdotelli per farsi scendong estrando i laghismo
# T: 0.5±.4  S: Kim Jong-un ai segorici muore di mare gia uomo in commile elettronica
# T: 1±.7    S: Kim Jong-un combaccho 12 atrifre di Olgoone quelle gli ottie ne nenaggini al forlura di Tar
# ------ L ------
# T: 0       S: La Chiesa apre ai matrimoni con l'arcoltava "manisce "Bestembili"
# T: 0.1     S: La Chiesa apre ai matrimoni con l'arcoltava "manisce "Bestembili"
# T: 0.5     S: La Crista e invia i calci non aumi la vita: "Ruba Mano Marolla"
# T: 0.7     S: Le difesa comincia regolamenti per la palle di Ferlanta che sono igieristro
# T: 0.9     S: LercioNews a Radio2 Social Club - 18 settembre 2015
# T: 0±.4    S: L'ideatore delle pincerci sul proprio navi delle Stato di Golverh
# T: 0.5±.4  S: Lotta allarge al corsola di profughi in difetta: costretto a decendere il matrimonio del 200
# T: 1±.7    S: La vittofis antima: il primo radume pubblicitaria: "Vieera sostituita alle promessa"
# ------ M ------
# T: 0       S: Mario Roga serie alle fredi e scopre che il proiettoli di Massimo Boldi
# T: 0.1     S: Mario Dio sbaglia la sua bagno va piu piu veganza
# T: 0.5     S: Matteo Salvini rimane ancora in vichenza del concerto dei Fabitti e Covatori Salvini
# T: 0.7     S: Morto l'inventore del kityttio a rischio il bambino si fa un iopo
# T: 0.9     S: MUORE ANDORETURAMU: PANERTRO DESSE PROVORATORE
# T: 0±.4    S: Mario Decideta in Sicilia: il Brashono si sfide a Telet
# T: 0.5±.4  S: Mattarella sulla Torre costruisce il suo campo causo di tornare
# T: 1±.7    S: Mucher. Sputajk: le accusa come pendettera in onde 20.000 euro
# ------ N ------
# T: 0       S: Napoli. Sequestrato attacca un combatto eviaggio anche la signora in stirico
# T: 0.1     S: Non ci sono mai non ucciso i primi automatico si supanda sedrestata di Stramba
# T: 0.5     S: New York Vond di Strada disoccupato perche quando chieso alla volamo
# T: 0.7     S: NoST. Domanicano autostrada 'I' Rai terromotto': Gesu contro un semplice e betti i comini
# T: 0.9     S: Nasce la prima sia cheo rossa gia trasfurto di post e solo alle fidestati
# T: 0±.4    S: Napoli. Bonguy Bongitrooke dell'acqua piu granne cliente legge dal Veton
# T: 0.5±.4  S: Nasce la prima raccoglie di Peppa Pieren. Blunchenelo 49 manito per deteniti in pagare ch'espo
# T: 1±.7    S: Napolitano Lega-scuola condutiny: "Radige i fugiardi BrAB"
# ------ O ------
# T: 0       S: Oriana Fassa Gussante non vaccinato: e stata la settimana con una scintica
# T: 0.1     S: Oriana Fassa Galdini ma si accorga anche da un computer vietato per farlo spettare e veri
# T: 0.5     S: OGMILIANI SUPPIATO AD DI FILINO E SI STAVENTO: 1UMANO TETTETTO PER MARTA PERCHI PESSO
# T: 0.7     S: Orieta Profranzo si dimette da cambia contro la chiare: pestito dai governi la cateresis
# T: 0.9     S: Olimpiadi invercottico per boss di cieccioli e scappa dalla Terre dei decidei
# T: 0±.4    S: Ordie Apedy. Quanda emergeni alle piccole a piecenziano in metteve e chiede
# T: 0.5±.4  S: Ozziste a forma di un'ora: nato di un clonere le sede di Gior di antitori: avere il nome di essere
# T: 1±.7    S: Operatori di Geovano viene. Anziano scarpe in bancato al primo film porno
# ------ P ------
# T: 0       S: Papa Francesco incontrera i sottiberibre 2015 di Studio essere ancora per ritrova la pace
# T: 0.1     S: Presentata la prossima sedia di nuoto e donne come mai all'assalto
# T: 0.5     S: Papa Francesco in visita di Forza Italia e riesce a pretiticadente le per finire i paganti
# T: 0.7     S: Primarie Papa Francesco scontri colta dell'anno
# T: 0.9     S: Presidente chiuso fra avversi allergico girare un misi di cocaina. Tomigliar esplonati
# T: 0±.4    S: Professore lo scrivo sulla testa al suo cucciolo di un Ginaco Mentana
# T: 0.5±.4  S: Papa Francesco: "Arosa le porto che va a tornare in contatto di coppie stodano?"
# T: 1±.7    S: PARLA DI CALVANARLI: ARRESSIATA ACCUMBO A TACK: EL FARCO TERRAMO DIL FORRUKA ALLAFMA IN ANCATECALITA
# ------ Q ------
# T: 0       S: Quali altre corte una modelle estete Marole e Batteo Marte Di Maio capocato da un candidato
# T: 0.1     S: Quali altre corte una modelle estete Marolagia: "Compra mai anche noi"
# T: 0.5     S: Quindicenne vince il premio glialo attore di Baraglietti e Ron esagorostra
# T: 0.7     S: Qualsiasco lancia "Misura a Casabio": Cristo di Padre Pio esse
# T: 0.9     S: Qualsiasa che sata dalle muore e una seda anente
# T: 0±.4    S: Qualsionale del Papa Mettadona al contrario"
# T: 0.5±.4  S: Quindicenne vince i trentismo"
# T: 1±.7    S: Qualdo di Boldro si trasferisce tutta la defia ascoltenda dente contemporaneamentti
# ------ R ------
# T: 0       S: Ricerca rivela: "Sono sciopero da Ramini cannaro la moglie cancellare i Strvelle"
# T: 0.1     S: Ricerca rivela: "Sono sciopero da Ramini avvisa "bibenico di partemiera e si tatuaggi"
# T: 0.5     S: Renzi si addormenta di morte del cabettolegista degli internetioni per due gialli
# T: 0.7     S: Ricerca rivela: "Putta per diventare al mondo testimosi la domesiria"
# T: 0.9     S: Ricercatori si governo mentre salva chi pesca e ritrova le state il 1232 nomicia
# T: 0±.4    S: Rimosse approva l'accusa sulla liberta di Dolle Chiese
# T: 0.5±.4  S: Romani vanno animalista dimentica lingua mentre e ancorcare la prova cera
# T: 1±.7    S: Renzi: "Sono scatta la faccia l'univorcati dei gato nella debla le dottti meri!"
# ------ S ------
# T: 0       S: Scoperto il colledio: "Dichiode di propoitori"
# T: 0.1     S: Scoperto il colledio: "Dichiode di propoitori"
# T: 0.5     S: Senatore del Vaticano: "Mia la documenti perche aveva materia della Lega chiamace dai sestitre"
# T: 0.7     S: Sgominato tenta di affida per un giornalista e la verina e il camoro che siamo sotto cara
# T: 0.9     S: Sionano mettere un miese claentestantenna completicamente curametti
# T: 0±.4    S: Scienza: scoperto il primo sondaggio scontri che se ne accolgo e viene diventano boril
# T: 0.5±.4  S: Scoperto un atto nelle beredito da che si dove sara il taseo dei bambini che l'accouna sfuggato pia gara
# T: 1±.7    S: Scatta sulla cosciena rivela che nuovo secondo e una neal merano
# ------ T ------
# T: 0       S: Trovato sottopolte da True: "Investe il concerto di San Showksstino "Nop ceapinte"
# T: 0.1     S: Trovato sottopolte da bullismo da Enibo scrive e rientergi: organdie di Angela
# T: 0.5     S: TG Lercio su Radio2 - 2 Novembre 2018
# T: 0.7     S: TG Lercio su Radio2 Week - 10 Agosto 2016
# T: 0.9     S: TG Lercio su Radio2 Weekend - 28 Settembre 2016
# T: 0±.4    S: Trovato sottopolotto di Microk per prendere l'uomo invisibile dall'Italia
# T: 0.5±.4  S: Trovato sul campo rimane dopo l'ultimo dighionenti
# T: 1±.7    S: T2 MaX dei piedi delle mani 500.000 Cadea dei Povinoni D'Aggitt agli-Scideona e dado
# ------ U ------
# T: 0       S: Uomo si fa tatuare sul pene un pene piu lungo
# T: 0.1     S: Universita della vita e superposostaliali invertato in un campo di nuoto
# T: 0.5     S: UE: "Critta di mette per la pace imprese di vivo del prenderma pensione seria lanciale a pasta scompare la schiante"
# T: 0.7     S: Un communtisce elettrime a morte
# T: 0.9     S: Un dite trappola introduce strappa: suicidarsi le spettamente e capille in Cinadia
# T: 0±.4    S: Un commento sulla carico di Papa Francesco: "Comprare la sposa paustava l'albandono pagare"
# T: 0.5±.4  S: UO: "BOPATO DELLA SCOPERGO SCOPERALE"
# T: 1±.7    S: Universimentto mischia la meta Bossinala da F35
# ------ V ------
# T: 0       S: Vince al corpo per la prima cellule somire all'arraia: "Nel 2017 la prima cazzo ma l'ammiglie"
# T: 0.1     S: Vince al corpo per ricostruire la sigaretta e raggiunge vedo annuncia
# T: 0.5     S: Venditore di Salvini scritte "Areurdi sponda tra il Giro d'Ale""
# T: 0.7     S: Vaticano che va a Fase: "I nostri fraspondiali di cammini"
# T: 0.9     S: Vastari Mancor che sara piavalsi su Yaus
# T: 0±.4    S: Valentina Nappi vince il premio "Miglior Rubrizia per la privalmatori"
# T: 0.5±.4  S: Vaticano. Fertilitti si lancia un suo sangue a sociale
# T: 1±.7    S: Vendono favorsiola dimentica di piu un armadio per rimiovere la sua credene a donna
# ------ W ------
# T: 0       S: Wikileaks: "La CIA concesso a casa sbagliata sentata le televisietti "Pezzano cambiata"esa il tutto collo e usareblion Joaur
# T: 0.1     S: Wikileaks: "La CIA concesso anche un bimbo nascono il contendente sengue"
# T: 0.5     S: Weinstein: "Ho molti un diazoonali di RaiB". San alle visita. W-E l'razzista divendare in ttardo di Stavani"
# T: 0.7     S: Wikileaks: "Lacciato il Gay Chamma e andra totto e la sua sedea"
# T: 0.9     S: Wasti di Afflica rivela: gli altanno lancia la statua la donna: nascondici davvirk
# T: 0±.4    S: Walter trova dichiaranno den grelisti a cazzo che va a quand di Annile Ilvider
# T: 0.5±.4  S: Walter Renzi: "Pedofili concede i testarsi intene in cura sono torna a cazzo albergo?"
# T: 1±.7    S: Wikileacottista Para un astituzione Rotembra X del Parla Rotti
# ------ X ------
# T: 0       S: Xylella fuori dal 20deg Dio Durgiarsio 'D'ILPA'PIATO CORCANTO CACCO CONTRO CONCETTO DELONICCANO
# T: 0.1     S: Xylella fuori dal 20deg Dio Durgiarsio 'D'ILPA'PIATO CORCANTO CACCO CONTRO CONCETTO DELONICCANO
# T: 0.5     S: Xylella fuori dal 20deg per piu decrotola di cazzo pornonieri aveva la ricossi
# T: 0.7     S: Xylella fuori chiede alla Ratazza della tenta su una cazzo di hatrovoro armo auto-barazzazzo
# T: 0.9     S: Xylella fa considersari anche per il Gry Vulli: "So perio a milare ai funele"
# T: 0±.4    S: X rivela: "Il cillo del Papa interno Lambio anche noi"
# T: 0.5±.4  S: Xeliala col strasta del Pugino. Il tratte di Marcotto cauri al cuore causa a Matenare costratta annistra
# T: 1±.7    S: Xelisarlo a Padania. Battisti l'abbattiare nel cadumento della fila al 2% su barbare omese una piaziani
# ------ Y ------
# T: 0       S: Yara. Peggiora la situazione di Pippo Cichett Blac
# T: 0.1     S: Yahoo In Branneria della privacy
# T: 0.5     S: Yahoo Di Battista chiedera rivela: "Do senasti agli autovelo a lue"
# T: 0.7     S: Yara. Peghesiatore cosere dai geniteri
# T: 0.9     S: Yara: scoperta testereva per glillel Noker
# T: 0±.4    S: Yahoo In Branneria della Gestica in contatte dallenta con un profilo
# T: 0.5±.4  S: Yahoo We-k--Bur. Sbalberolo. Sulle usanoli del Wiplene
# T: 1±.7    S: Yara: spornare 80 manova"
# ------ Z ------
# T: 0       S: Zoologia: il calcio a letto il divorzio del tempo di condrelle per le propria paladerano
# T: 0.1     S: Zoologia: il 2000 America 2015 - Radio2 e inoscera farso uccide un arocolli
# T: 0.5     S: Zoologia: il compagno di sabbia sesso ora del tempo abbiamo piu puntata di bollo del finghio
# T: 0.7     S: Zoologi rivoltato solo ai identi nascito degli imitigini piu il destinseolate
# T: 0.9     S: Zuoleni mail compiato noi cloccare la mignottare. A girandono siamore di prima ai peneuni
# T: 0±.4    S: Zoologia: il 2000 America 2015 - Radio2 e ascolo addormora antitorci
# T: 0.5±.4  S: Zoologia: il calcio a bere di shock alle vista con mentana
# T: 1±.7    S: Zoologo 49 miliando di covisbilenti moglieto Not duegno

# %% [markdown]
# ### Results
#
# Above are shown some phrases generated with different models and at different temperatures.
# Also shown are the loss curves for each one.
#
# It can be seen how much the hidden size is correlated with the loss: a simple change from 290 to 300 hidden units made in this case a difference of 0.10 in the loss, and a drastic difference in the quality of the generated phrases.
# Also, the impact of dropout is not shown as i was not able to train a model with dropout which did not underfit.
# From the loss curves, it can be seen that there are some spikes. The situation was much worse before the implementation of gradient clipping and the scheduling of the learning rate (to the point that before that, this results were unimaginable).
#
# ##### H350_N2_D0.00_E1069_L0.05_rnn.pt
#
# This model was trained with an hidden size of 350, 2 layers, dropout of 0.00. The final loss was 0.05.
# As can be seen, at low temperatures, the model outputs only phrases from the training set, while at higher temperatures it tends to generate less readable phrases. The `generate_normal` does not seem to improve the results.
#
# Examples:
#
#
#
# ##### H300_N2_D0.10_E609_L0.27_rnn.pt
#
# This model was trained with an hidden size of 300, 2 layers and a dropout of 0.10. The final loss was 0.27.
# In this case, the vast majority of the generated phrases have no meaning whatsoever.
# At low temperature the phrases are mostly composed of real words but with no meaning in their order, while at higher temperatures the generated words are mostly gibberish.
#
# Examples:
#
#
#
# ##### H300_N2_D0.00_E725_L0.13_rnn.pt
#
# This one is a decent tradeoff between the others. It was trained with an hidden size of 300, 2 layers and a dropout of 0.00. The final loss was 0.13.
# In the generated phrases, it is possible to find some phrases from the training set (mostly at low temperatures), and some nonsensical phrases.
# However, it is still possible to see some (roughly) correct phrases which are not present in the training set.
#
# ### Conclusions
#
# One big limiting factor of this model is the lack of a metric for evaluation: some candidates could be:
# - The loss on a validation set (given the small size of the dataset and the high diversity in the headlines, I was not able to implement this properly)
# - Proportion of generated words present in a dictionary; this however would not take into account the order of the words.
# - A carefully crafted metric which would `reward` known (good) sequences of words while penalizing blatant copies of the training set in order to avoid overfitting.
# - A human evaluation; which is roughly what I did, but it is not very reliable.
#
# ### Funny results
#
# During the training, I saved the headlines which made me giggle. Here are some of them:
#
# _Di Maio rivela: "Sono solo solo solo solo con le parte di parte di Barkandi"_ (To read in the style of a Marco Mengoni's song)
#
# _La Chiesa apre ai matrimoni tra omosessuali di m***a_ (Like every good model, even mine had to be somewhat offensive, see Meta's BlenderBot3 racism scandal from Aug. 2022)
#
# _Trovato il gatto che ha mangiare i dati 1.008"_ (The cat has eaten the data mid sentence, breaking the model)
#
# _LercioNews a Radio2 Social Club - 36 ottobre 2015_ (Apparently October has 36 days now)
#
# _Washington: estremista testimone di Geova che non parla inculittiva clandestini_ (This one was almost there)
#
# _Berlusconi scopre che andra al suo post di condominio del PD si arrende_ (this too)
